# %%
# !curl ifconfig.me

# %%
# !pip install selenium

# %%
#please place your youtube playlist or live or video code here with sleep time at the end for 10 hours
##############################################
import time
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('window-size=1366,768')
#options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
import os,time,datetime
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
options.add_argument('--profile-directory=Default')
#options.add_argument('--user-data-dir=/root/.config/chromium')
driver = webdriver.Chrome('chromedriver',options=options)
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException,TimeoutException,InvalidArgumentException,ElementClickInterceptedException
from selenium.webdriver.support.ui import WebDriverWait
driver.implicitly_wait(15)
driver.get("https://www.youtube.com/watch?v=gjpqXDnZs80&list=PLF6tm78v4wxv-K8Yd4T2MsVhWKvcyd0ae")
time.sleep(15)
try:
    driver.find_element_by_xpath("//*[@class='ytp-large-play-button ytp-button'][@aria-label='Play']").click()
except:
    print("already playing")
try:
    driver.find_element_by_xpath("//button[@aria-label='Shuffle playlist']").click()
except:
    print("shuffel not clicked")
try:
    driver.find_element_by_xpath("//button[@aria-label='Loop playlist']").click()
except:
    print("loop not clicked")
    #if machine instance is active for more then half hour then this works
#if machine instance is active for more then half hour then this works
##############################################
#time below is permanent for this script
tab=0
driver.execute_script("window.open('about:blank');")
driver.switch_to.window(driver.window_handles[tab+1])
driver.get("https://twitter.com/BobyMomi/")
driver.find_element_by_xpath("//*[text()='adzbux.com/quick.php?u=59']").click()
time.sleep(25)
#ad script
driver.close()
driver.switch_to.window(driver.window_handles[tab])
for i in range(1000):
    driver.execute_script("window.open('about:blank');")
    driver.switch_to.window(driver.window_handles[tab+1])
    driver.get("https://mybinder.org/v2/gh/KaalKala21/apt_install.git/HEAD?filepath=BinderViewAdReaction.ipynb")
    time.sleep(60)
    try:
        driver.find_element_by_xpath("//*[text()='Cell']").click()
        driver.find_element_by_xpath("//*[text()='Run All']").click()
    except:
        print("failed,skipping it")
    time.sleep(3)
    driver.close()
    driver.switch_to.window(driver.window_handles[tab])
time.sleep(36000)

# %%
# !curl ifconfig.me
